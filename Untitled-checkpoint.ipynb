# %% [markdown]
# <h1>US-Accidents: A Countrywide Traffic Accident Dataset Analysis</h1>
#
# This dataset captures approximately <b>1 million</b> car accident records across 47 U.S. states, collected between February 2016 and December 2019. Data was sourced through real-time APIs integrating inputs from transportation departments, law enforcement, traffic cameras, and road sensors. </br>
#
# <h3>What is Exploratory Data Analysis (EDA)?</h3>
# EDA is the process of exploring and analyzing datasets to uncover patterns, trends, and insights using statistical summaries and visualizations. It blends statistical rigor with creative inquiry, relying on tools like NumPy, Pandas, Seaborn, and more, while also requiring critical thinking and interpretation skills.</br>
#
# <h4>Project Objective:</h4>
# In this project, I’m conducting EDA on the US Accidents (2016–2019) dataset from Kaggle. The goal is to deeply understand the dataset, extract meaningful insights, and prepare the data for further modeling. For this, I’ll utilize Python libraries such as pandas, matplotlib, seaborn, plotly, and folium.</br>

# %%
# !pip install pandas
import pandas as pd
df = pd.read_csv('US_Accidents.csv')
df
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#                 ID  Severity        Start_Time          End_Time  Start_Lat  \
# 0        A-2716600         3  08-02-2016 00:37  08-02-2016 06:37  40.108910
# 1        A-2716601         2  08-02-2016 05:56  08-02-2016 11:56  39.865420
# 2        A-2716602         2  08-02-2016 06:15  08-02-2016 12:15  39.102660
# 3        A-2716603         2  08-02-2016 06:15  08-02-2016 12:15  39.101480
# 4        A-2716604         2  08-02-2016 06:51  08-02-2016 12:51  41.062130
# ...            ...       ...               ...               ...        ...
# 1048570  A-3771908         2  10-12-2019 17:05  10-12-2019 17:58  33.195825
# 1048571  A-3771909         2  10-12-2019 17:02  10-12-2019 18:33  33.901813
# 1048572  A-3771910         2  10-12-2019 17:11  10-12-2019 18:24  33.651594
# 1048573  A-3771911         2  10-12-2019 17:04  10-12-2019 20:19  35.419703
# ...

# %% [markdown]
# The dataset contains over 1048575 rows and 47 columns. The data is collected from 08-02-2016 to 10-12-2019.

# %% [markdown]
# <h2>Data preparation and cleaning with Pandas</h2>

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   ID                     1048575 non-null  object
#  1   Severity               1048575 non-null  int64
#  2   Start_Time             1048575 non-null  object
#  3   End_Time               1048575 non-null  object
#  4   Start_Lat              1048575 non-null  float64
#  5   Start_Lng              1048575 non-null  float64
#  6   End_Lat                1048575 non-null  float64
#  7   End_Lng                1048575 non-null  float64
#  8   Distance(mi)           1048575 non-null  float64
#  9   Description            1048575 non-null  object
#  10  Number                 360065 non-null   float64
#  11  Street                 1048575 non-null  object
#  12  Side                   1048575 non-null  object
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   2.164623e+00  3.646292e+01 -9.720202e+01  3.646305e+01 -9.720181e+01
# std    5.460908e-01  5.165882e+00  1.831984e+01  5.165957e+00  1.831963e+01
# min    1.000000e+00  2.457058e+01 -1.244975e+02  2.457433e+01 -1.244975e+02
# 25%    2.000000e+00  3.371034e+01 -1.180358e+02  3.371188e+01 -1.180361e+02
# 50%    2.000000e+00  3.635720e+01 -9.292586e+01  3.635665e+01 -9.292828e+01
# 75%    2.000000e+00  4.023489e+01 -8.038426e+01  4.023471e+01 -8.038469e+01
# max    4.000000e+00  4.900058e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)         Number  Temperature(F)  Wind_Chill(F)  \
# count  1.048575e+06  360065.000000    1.017832e+06  813974.000000
# mean   5.867531e-01    7869.769653    5.915797e+01      55.283185
# std    1.601684e+00   15619.751306    1.778244e+01      20.048839
# ...

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

numeric_df = df.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 14

# %% [markdown]
# There are 14 numer of numeric columns in the Dataframe.

# %%
df.isna()
# Out:
#             ID  Severity  Start_Time  End_Time  Start_Lat  Start_Lng  End_Lat  \
# 0        False     False       False     False      False      False    False
# 1        False     False       False     False      False      False    False
# 2        False     False       False     False      False      False    False
# 3        False     False       False     False      False      False    False
# 4        False     False       False     False      False      False    False
# ...        ...       ...         ...       ...        ...        ...      ...
# 1048570  False     False       False     False      False      False    False
# 1048571  False     False       False     False      False      False    False
# 1048572  False     False       False     False      False      False    False
# 1048573  False     False       False     False      False      False    False
# 1048574  False     False       False     False      False      False    False
#
# ...

# %% [markdown]
# No data is missing which is great to work with.

# %%
missing_percentages = df.isna().sum().sort_values(ascending=False) / len(df)
missing_percentages
# Out:
# Number                   0.656615
# Precipitation(in)        0.247232
# Wind_Chill(F)            0.223733
# Wind_Speed(mph)          0.064764
# Humidity(%)              0.031254
# Wind_Direction           0.029605
# Visibility(mi)           0.029388
# Temperature(F)           0.029319
# Weather_Condition        0.028858
# Pressure(in)             0.024281
# Weather_Timestamp        0.021091
# Airport_Code             0.002535
# Timezone                 0.001101
# Zipcode                  0.000466
# Sunrise_Sunset           0.000066
# Civil_Twilight           0.000066
# Nautical_Twilight        0.000066
# Astronomical_Twilight    0.000066
# City                     0.000066
# Country                  0.000000
# Give_Way                 0.000000
# Start_Time               0.000000
# End_Time                 0.000000
# Start_Lat                0.000000
# Turning_Loop             0.000000
# Traffic_Signal           0.000000
# Traffic_Calming          0.000000
# ...

# %% [markdown]
# This calculates the percentage of missing values in each column of your dataset and then sorts these percentages in descending order.

# %%
type(missing_percentages)
# Out:
# pandas.core.series.Series

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt
missing_percentages[missing_percentages != 0].plot(kind='barh')
plt.title('Non-Zero Missing Percentages')
plt.show()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# The bar chart of the percentage of missing values for some feature in the dataset. The y-axis shows the percentage of missing values, and the x-axis shows the feature name.
#
# The most valuable insight that can be drawn from this chart is that there is a significant amount of missing data for many of the features in the dataset. For example, the feature "End_lng" and "End_lat" (Number) has over 60% missing values, and the feature "Zipcode ", "City", "Zipcode" almost close to 0% missing values.

# %% [markdown]
# <h2>Exploratory Analysis and Visualization </h2>
#
# <b>Columns we'll analyze:</b>
#
# 1. City
# 2. Start Time
# 3. Start Lat, Start Lng
# 4. Temperature
# 5. Weather Condition

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %% [markdown]
# <h2>1. City</h2>

# %%
df.City
# Out:
# 0               Dublin
# 1               Dayton
# 2           Cincinnati
# 3           Cincinnati
# 4                Akron
#               ...
# 1048570      Oceanside
# 1048571      Riverside
# 1048572         Irvine
# 1048573    Bakersfield
# 1048574        Anaheim
# Name: City, Length: 1048575, dtype: object

# %%
cities = df.City.unique()
len(cities)
# Out:
# 9601

# %%
cities_by_accident = df.City.value_counts()
cities_by_accident
# Out:
# City
# Miami            30848
# Los Angeles      26699
# Charlotte        18749
# Houston          14395
# Dallas           14182
#                  ...
# Limerick             1
# Mannington           1
# Judith Gap           1
# Mancos               1
# Robinsonville        1
# Name: count, Length: 9600, dtype: int64

# %%
cities_by_accident[:20]
# Out:
# City
# Miami          30848
# Los Angeles    26699
# Charlotte      18749
# Houston        14395
# Dallas         14182
# Orlando        12912
# Sacramento     12722
# San Diego       9367
# Minneapolis     9129
# Raleigh         8287
# Saint Paul      7408
# Richmond        7100
# Phoenix         7098
# Nashville       6911
# Portland        6812
# Baton Rouge     6636
# Tucson          6606
# Atlanta         6480
# Austin          6259
# Chicago         6087
# Name: count, dtype: int64

# %%
type(cities_by_accident)
# Out:
# pandas.core.series.Series

# %%
cities_by_accident[:20].plot(kind='barh')
plt.title("Top 20 Cities by Accident Count")
plt.show()

# %% [markdown]
# The image shows the top 20 cities in the US with the highest number os accidents, but we cannot specify what type of accidents or the time period over which the data was collected.

# %%
import seaborn as sns
sns.set_style("darkgrid")

# %%
sns.histplot(cities_by_accident, log_scale=True)
plt.title("Histogram of Citiesby Accident (Log Scale)")
plt.show()

# %% [markdown]
# The code sns.histplot(cities_by_accident, log_scale = True) will create a histogram of the number of accidents in each city, with the y-axis on a logarithmic scale.
#
# The histogram will show the distribution of the number of accidents in each city. The x-axis will show the number of accidents, and the y-axis will show the number of cities with that number of accidents. The bars in the histogram will be sorted in descending order by the number of accidents.

# %%
cities_by_accident[cities_by_accident == 1]
# Out:
# City
# Nassawadox       1
# Cummington       1
# Mifflin          1
# Walpole          1
# Amelia           1
#                 ..
# Limerick         1
# Mannington       1
# Judith Gap       1
# Mancos           1
# Robinsonville    1
# Name: count, Length: 1111, dtype: int64

# %% [markdown]
# The list of cities with only 1 accident is a diverse group of cities, ranging in size from very small towns to medium-sized cities. The cities are located in different parts of the United States, and there is no clear pattern to their distribution.
#
# Here are some possible explanations for why these cities have only 1 accident each:
#
# <b>Small population density:</b> Cities with a low population density are likely to have less traffic, which can reduce the risk of accidents.<br/>
# <b>Good road conditions:</b> Cities with good road conditions are less likely to have accidents caused by potholes, uneven surfaces, or other road hazards.<br/>
# <b>Safe driving practices:</b> Residents of cities with only 1 accident each may be more likely to drive safely and obey traffic laws. This could be due to a number of factors, such as public awareness campaigns, law enforcement efforts, or a strong sense of community. <br/>
# It is also possible that there is some random chance involved in why these cities have only 1 accident each. For example, a city with a small population density may simply have been lucky enough to avoid accidents during the time period that the data was collected.

# %% [markdown]
# <h2>2. Start Time </h2>

# %%
df.Start_Time
# Out:
# 0          08-02-2016 00:37
# 1          08-02-2016 05:56
# 2          08-02-2016 06:15
# 3          08-02-2016 06:15
# 4          08-02-2016 06:51
#                  ...
# 1048570    10-12-2019 17:05
# 1048571    10-12-2019 17:02
# 1048572    10-12-2019 17:11
# 1048573    10-12-2019 17:04
# 1048574    10-12-2019 17:02
# Name: Start_Time, Length: 1048575, dtype: object

# %%
df['Start_Time'] = pd.to_datetime(df['Start_Time'], format='mixed', dayfirst=True,errors='coerce')

# %%
import matplotlib.pyplot as plt
sns.distplot(df['Start_Time'].dt.hour, bins=24, kde=False, norm_hist=True)

plt.title("Distribution of Start Time Hours")

plt.show()
# Out:
# C:\Users\Tina\AppData\Local\Temp\ipykernel_3068\2074447313.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Start_Time'].dt.hour, bins=24, kde=False, norm_hist=True)

# %% [markdown]
# A high percentage of accidents occur between 4 pm to 6pm and next highest percentage is between 8 am to 9 am (probably people in hurry to get to work).

# %%
sns.distplot(df.Start_Time.dt.dayofweek, bins = 7, kde = False, norm_hist=True)
plt.title("Distribution of Days of the Week for Start Time")
plt.show()
# Out:
# C:\Users\Tina\AppData\Local\Temp\ipykernel_3068\1473810541.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.dayofweek, bins = 7, kde = False, norm_hist=True)

# %% [markdown]
# Is the distribution accidents by hour the same on weekends as on weekdays.

# %%
weekends = df.Start_Time[(df.Start_Time.dt.dayofweek == 6) | (df.Start_Time.dt.dayofweek == 5)]
sns.distplot(weekends.dt.hour, bins = 24, kde = False, norm_hist=True)
plt.title("Distribution of Start Time Hours on Weekends")

plt.show()
# Out:
# C:\Users\Tina\AppData\Local\Temp\ipykernel_3068\4261425598.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(weekends.dt.hour, bins = 24, kde = False, norm_hist=True)

# %%
weekdays = df.Start_Time[(df.Start_Time.dt.dayofweek >= 0) | (df.Start_Time.dt.dayofweek <= 4) ]
sns.distplot(weekdays.dt.hour, bins = 24, kde = False, norm_hist=True)
plt.title("Distribution of Start Time Hours on Weekdays")

plt.show()
# Out:
# C:\Users\Tina\AppData\Local\Temp\ipykernel_3068\2765533580.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(weekdays.dt.hour, bins = 24, kde = False, norm_hist=True)

# %%
months = sns.distplot(df[(df['Start_Time'] >= '2016-02-01') & (df['Start_Time'] <= '2023-03-31')].Start_Time.dt.month, bins = 12, kde = False, norm_hist=True)
plt.title("Distribution of Months in the Specified Date Range")
plt.show()
# Out:
# C:\Users\Tina\AppData\Local\Temp\ipykernel_3068\1185281443.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   months = sns.distplot(df[(df['Start_Time'] >= '2016-02-01') & (df['Start_Time'] <= '2023-03-31')].Start_Time.dt.month, bins = 12, kde = False, norm_hist=True)

# %% [markdown]
# The month-wise trend of accidents shown in the graph shows that the number of accidents is lowest in the summer months (March, May, June and July) and highest in the winter months (November, Decemberand January). And the reason behind it could be the weather during winter is snowy which makes it difficult for a person to drive as the road may be cover with thin layer of ice unlike during summers.

# %%
months = sns.distplot(df.Start_Time.dt.year, bins = 12, kde = False, norm_hist=True)
plt.title("Distribution of Years from Start Time")
plt.show()
# Out:
# C:\Users\Tina\AppData\Local\Temp\ipykernel_3068\2404607228.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   months = sns.distplot(df.Start_Time.dt.year, bins = 12, kde = False, norm_hist=True)

# %%
df.Start_Time.dt.year
# Out:
# 0          2016.0
# 1          2016.0
# 2          2016.0
# 3          2016.0
# 4          2016.0
#             ...
# 1048570    2019.0
# 1048571    2019.0
# 1048572    2019.0
# 1048573    2019.0
# 1048574    2019.0
# Name: Start_Time, Length: 1048575, dtype: float64

# %%
import matplotlib.pyplot as plt

# Extract the year
df['Year'] = df['Start_Time'].dt.year

# Define the years to plot
years_to_plot = [2016, 2017, 2018, 2019, 2020]

# Create separate histograms for each year
for year in years_to_plot:
    # Filter data for the specific year
    year_data = df[df['Year'] == year]
    
    # Create a new figure and axis for each year
    plt.figure(figsize=(8, 6))
    
    # Create a distogram for the annual accidents using Seaborn
    sns.distplot(year_data['Start_Time'], bins=12, kde=False)
    
    # Set labels and title
    plt.ylabel('Number of Accidents')
    plt.title(f'Distribution of Accidents in {year}')
    
    # Show the plot
    plt.show()
# Out:
# C:\Users\Tina\AppData\Local\Temp\ipykernel_3068\921038252.py:18: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(year_data['Start_Time'], bins=12, kde=False)

# %% [markdown]
# <h2>Start Latitude and Start Longitude</h2>

# %%
df.Start_Lat
# Out:
# 0          40.108910
# 1          39.865420
# 2          39.102660
# 3          39.101480
# 4          41.062130
#              ...
# 1048570    33.195825
# 1048571    33.901813
# 1048572    33.651594
# 1048573    35.419703
# 1048574    33.806080
# Name: Start_Lat, Length: 1048575, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -83.092860
# 1          -84.062800
# 2          -84.524680
# 3          -84.523410
# 4          -81.537840
#               ...
# 1048570   -117.367005
# 1048571   -117.466712
# 1048572   -117.761153
# 1048573   -119.012848
# 1048574   -117.880100
# Name: Start_Lng, Length: 1048575, dtype: float64

# %%
sns.scatterplot(x = df.Start_Lng, y = df.Start_Lat, sizes = (10,200))
plt.title("Scatterplot of Latitude vs. Longitude")

plt.show()

# %%
sample_df = df.sample(int(0.1 * len(df)))
sns.scatterplot(x = sample_df.Start_Lng, y = sample_df.Start_Lat, size = 0.001)
plt.title("Scatterplot of Latitude vs. Longitude")

plt.show()

# %%
# !pip install folium
import folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# # Create a map object
# map = folium.Map()

# # Iterate over the Start_Lat and Start_Lng columns for the first 10 rows
# for lat, lon in zip(df['Start_Lat'][:10000], df['Start_Lng'][:10000]):
#     marker = folium.Marker((lat, lon))
#     marker.add_to(map)

# # Display the map
# map

# %% [markdown]
# This map in pin pointing towards the 1000 area where accidents has too place.

# %%
# #import folium
# from folium.plugins import HeatMap

# # Create a Folium map
# m = folium.Map()

# # Create a HeatMap layer with your data
# heat_data = list(zip(df['Start_Lat'][:1000], df['Start_Lng'][:1000]))
# HeatMap(heat_data).add_to(m)

# # Fit the map view to contain all the points
# m.fit_bounds(heat_data)

# # Show the map
# m

# %% [markdown]
# This heat map is showing data of first 1000 cities. Most of them are from California.

# %% [markdown]
# <h2>4. Temperature</h2>

# %%
df['Temperature(F)']
# Out:
# 0          42.1
# 1          36.9
# 2          36.0
# 3          36.0
# 4          39.0
#            ...
# 1048570    59.0
# 1048571    62.0
# 1048572    63.0
# 1048573    53.0
# 1048574    63.0
# Name: Temperature(F), Length: 1048575, dtype: float64

# %%
# Categorize temperatures into "cold" or "warm"
df['Temperature Category'] = df['Temperature(F)'].apply(lambda x: 'Cold' if x <= 0 else 'Warm')

# Group data by temperature category and count accidents
category_counts = df['Temperature Category'].value_counts().reset_index()
category_counts.columns = ['Temperature Category', 'Accident Count']

# Create a bar graph
plt.figure(figsize=(8, 6))
plt.bar(category_counts['Temperature Category'], category_counts['Accident Count'], color='skyblue')
plt.xlabel('Temperature Category')
plt.ylabel('Number of Accidents')
plt.title('Accidents in Colder and Warmer Areas')
plt.show()

# %% [markdown]
# As we can see in the graph that the Warmer place has high number of accidents as compare to the colder place. or we can say that colder place in not even showing any data. Possible reasons could be that all places listed in has only accidents during warm seasons or they may some misinformation is stored.

# %% [markdown]
# <h2>5. Weather Conditions</h2>

# %%
df['Weather_Condition']
# Out:
# 0             Light Rain
# 1             Light Rain
# 2               Overcast
# 3               Overcast
# 4               Overcast
#                ...
# 1048570    Mostly Cloudy
# 1048571           Cloudy
# 1048572           Cloudy
# 1048573           Cloudy
# 1048574           Cloudy
# Name: Weather_Condition, Length: 1048575, dtype: object

# %%
# Calculate the average number of accidents for each weather condition
weather_avg_accidents = df['Weather_Condition'].value_counts()
weather_avg_accidents
# Out:
# Weather_Condition
# Fair                     370030
# Cloudy                   135175
# Mostly Cloudy            134722
# Partly Cloudy             86713
# Clear                     85601
#                           ...
# Freezing Rain / Windy         1
# Light Fog                     1
# Thunder and Hail              1
# Drifting Snow                 1
# Sand                          1
# Name: count, Length: 103, dtype: int64

# %%
# Create a bar plot
plt.figure(figsize=(20, 6))
weather_avg_accidents.plot(kind='bar', color='skyblue')
plt.title("Average Accidents by Weather Condition")
plt.xlabel("Weather Condition")
plt.ylabel("Average Number of Accidents")
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

# Show the plot
plt.show()

# %% [markdown]
# This graph is showing that FAIR weather condition has the highest number of accidents.

# %% [markdown]
# </br><h3>CONCLUSION</h3>

# %% [markdown]
# <b>1. High Accident Frequency in Urban Areas:</b> The top 5 cities with the highest number of accidents are all major urban areas. Miami, Houston, Los Angeles, Charlotte, and Dallas are densely populated regions with extensive road networks. This suggests that urban areas tend to have a higher frequency of accidents, which could be attributed to increased traffic, congestion, and various road conditions.</br>
#
# <b>2. Geographic Variation:</b> The distribution of accidents is not uniform across different cities. Some cities have significantly higher accident numbers than others. This indicates that the factors contributing to accidents, such as weather conditions, road infrastructure, and driver behavior, can vary widely from one location to another.</br>
#
# <b>3. Safety Initiatives:</b> These findings can be valuable for local authorities and transportation departments. They may use this data to prioritize safety initiatives, such as improving road infrastructure, enhancing traffic management, and promoting safe driving practices in cities with high accident rates.</br>
#
# <b>4. Resource Allocation:</b> The cities listed may need to allocate additional resources to address road safety and reduce the number of accidents. This could include investments in traffic monitoring, law enforcement, and public awareness campaigns to mitigate accidents.</br>
#
# <b>5. Data-Driven Decision-Making:</b> These statistics underscore the importance of data-driven decision-making in addressing traffic safety issues. By analyzing accident data, authorities can make informed choices to enhance safety and reduce accidents in areas with a high incidence of accidents.</br>
# </br>
# <i><h4>In summary, the data indicates that urban areas, particularly the listed cities, face challenges in terms of road safety, and addressing these challenges may require targeted efforts and initiatives.</h4></i>
